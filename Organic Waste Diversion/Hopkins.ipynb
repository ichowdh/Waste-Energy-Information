# %%
import folium
import pandas as pd
from folium import plugins
import ipywidgets
import geopy

# %%
jhu = [39.33105 , -76.62050]
jhu_map23 = folium.Map(location=jhu, zoom_start=16, control_scale=True)
locations = [
    [39.33125, -76.61951, "Hopkins Cafe"],
    [39.33672, -76.62882, "Keswick"],
    [39.32811, -76.62169, "Levering"],
    [39.32915, -76.61941, "Library"],
    [39.36988, -76.65489, "Mt. Washington Conference Center"],
    [39.37436, -76.65628, "Mt. Washington Marbury Building"],
    [39.33051, -76.62054, "Mudd Hall"],
    [39.32876, -76.61687, "Wolman + Nolans"],
    [39.33098, -76.62525, "Old Carnegie"],

    [39.29717, -76.61496, "Peabody Conservatory"],
    
    [39.29670, -76.59057, "School of Nursing"],
    
    [39.29779, -76.59041, "Bloomberg Building"],
    [39.29789, -76.59456, "Hampton House"],
    [39.29731, -76.58601, "2213 McElderry St."],
    
    [39.29541, -76.59619, "CRB / 1550 Orleans"],
    [39.29923, -76.59332, "1721 Madison"],
    [39.29910, -76.58833, "2024 E. Monument"],
    [39.29747, -76.59553, "MEB Bldg."],
]

for loc in locations:
    folium.CircleMarker(
        location=[loc[0], loc[1]],
        radius=15,  # Radius of the circle marker
        color='red',  # Border color of the circle
        fill=True,  # Whether to fill the circle
        fill_color='red',  # Fill color
        fill_opacity=0.6,  # Opacity of the fill color
        popup=loc[2]  # Popup message
    ).add_to(jhu_map23)
#jhu_map23.save('jhu.html')
jhu_map23
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
jhu = [39.33105 , -76.62050]
jhu_map24 = folium.Map(location=jhu, zoom_start=16, control_scale=True)
locations = [
    [39.33125, -76.61951, "Hopkins Cafe"],
    [39.33672, -76.62882, "Keswick"],
    [39.32811, -76.62169, "Levering"],
    [39.32915, -76.61941, "Library"],
    [39.36988, -76.65489, "Mt. Washington South: McAuley Conference Center"],
    [39.37436, -76.65628, "Mt. Washington North: Marbury Building"],
    [39.33051, -76.62054, "Mudd Hall + Animal Bedding"],
    [39.32876, -76.61687, "Wolman + Nolans"],
    [39.33098, -76.62525, "Old Camegie"],

    [39.29717, -76.61496, "Peabody Conservatory"],
    
    [39.29670, -76.59057, "School of Nursing"],
    
    [39.29779, -76.59041, "Bloomberg Building"],
    [39.29789, -76.59456, "Hampton House"],
    [39.29731, -76.58601, "2213 McElderry St."],
    
    [39.29541, -76.59619, "CRB / 1550 Orleans"],
    [39.29923, -76.59332, "1721 Madison"],
    [39.29910, -76.58833, "2024 E. Monument"],
    [39.29747, -76.59553, "MEB Bldg."],
]

for loc in locations:
    folium.CircleMarker(
        location=[loc[0], loc[1]],
        radius=15,  # Radius of the circle marker
        color='red',  # Border color of the circle
        fill=True,  # Whether to fill the circle
        fill_color='red',  # Fill color
        fill_opacity=0.6,  # Opacity of the fill color
        popup=loc[2]  # Popup message
    ).add_to(jhu_map)
#jhu_map24.save('jhu.html')
jhu_map24

# %%
df_suburbs = pd.read_excel('organic.xlsx', sheet_name='Sheet 1')

df_suburbs.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/notebook-7.0.6/lib/python3.11/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /opt/anaconda3/envs/notebook-7.0.6/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...
